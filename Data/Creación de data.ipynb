# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import random

data = {'Datos_aleatorios': random.sample(range(60000), 50000)}

df = pd.DataFrame(data, columns= ['Datos_aleatorios'])

df.to_csv(r'/content/drive/MyDrive/Practica 01/Data/Data50000.csv', index = False)
print(df)
# Out:
#        Datos_aleatorios
# 0                 37065
# 1                 21132
# 2                 15290
# 3                  3637
# 4                 46705
# ...                 ...
# 49995             29190
# 49996             53989
# 49997             21314
# 49998             30069
# 49999             40204
#
# [50000 rows x 1 columns]
